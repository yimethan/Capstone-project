# %%
import pandas as pd
import os

# %%
path = "/content/user_data"

# %%
files = os.listdir(path)

# %%
df = pd.DataFrame()

for file in files:
  if file.startswith('library'):
    df = pd.concat([df, pd.read_excel(os.path.join(path, file))])

# %%
spring_df = df[df['result']=='봄 웜톤']

# %%
summer_df = df[df['result']=='여름 쿨톤']

# %%
fall_df = df[df['result']=='가을 웜톤']

# %%
winter_df = df[df['result']=='겨울 쿨톤']

# %%
spring_df.frame_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='frame_num'>

# %%
summer_df.frame_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='frame_num'>

# %%
fall_df.frame_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='frame_num'>

# %%
winter_df.frame_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='frame_num'>

# %%
spring_df.light_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='light_num'>

# %%
summer_df.light_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='light_num'>

# %%
fall_df.light_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='light_num'>

# %%
winter_df.light_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='light_num'>

# %%
all_df = pd.concat([df, pd.read_excel(os.path.join(path, 'uic_expo.xlsx'))])

# %%
library_1111 = pd.read_excel(os.path.join(path, 'library_1111.xlsx'))

# %%
library_1112 = pd.read_excel(os.path.join(path, 'library_1112.xlsx'))

# %%
library_1114 = pd.read_excel(os.path.join(path, 'library_1114.xlsx'))

# %%
uic_expo = pd.read_excel(os.path.join(path, 'uic_expo.xlsx'))

# %%
spring_expo = uic_expo[uic_expo['result'] == '봄 웜톤']
spring_expo.light_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='light_num'>

# %%
summer_expo = uic_expo[uic_expo['result'] == '여름 쿨톤']
summer_expo.light_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='light_num'>

# %%
fall_expo = uic_expo[uic_expo['result'] == '가을 웜톤']
fall_expo.light_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='light_num'>

# %%
winter_expo = uic_expo[uic_expo['result'] == '겨울 쿨톤']
winter_expo.light_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='light_num'>

# %%
spring_expo.frame_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='frame_num'>

# %%
summer_expo.frame_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='frame_num'>

# %%
fall_expo.frame_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='frame_num'>

# %%
winter_expo.frame_num.value_counts().plot.bar()
# Out:
# <Axes: xlabel='frame_num'>
